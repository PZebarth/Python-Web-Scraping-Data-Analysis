# %% [markdown]
# ## Wrangling Data and Scrapping Twitter's API

# %% [markdown]
# Paul Zebarth

# %% [markdown]
# ### This is an analysis of WeRateDogs Twitter feed

# %% [markdown]
# I assessed the data given and determined the data I needed to scrape from Twitter's API. I used visual and programmatic inspection using basic functions like: sample( ), head( ), info( ), value_counts( ) and duplicated( ). I identified the problems and cleaned the data to make visuals.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Suprisingly, I discovered the average rating on we rate dogs to be 11.45/10. The distribution is also evidently left skewed. This is not good news for all the good boys out there who are being underrated.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The good news is we can solve this problem by looking at this scatter plot. If you want to help the good boys get the recognition they deserve, retweeting looks to be linearly correlated to favourite counts.

# %% [markdown]
# If I had more time I would make a multiple liner regression model to determine which variables affect each other the most. This way we can learn if our favoiurites are really helping the good boys get the ratings we need them to.
